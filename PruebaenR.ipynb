# %%
train<-read.csv('./data/train.csv',stringsAsFactors=FALSE)
test<-read.csv('./data/test.csv',stringsAsFactors=FALSE)

# %%
train
# Out:
#        id     duration start_date
# 1      907649  396     8/27/2015 8:36
# 2      384043  636     7/28/2014 22:06
# 3      316176  334     6/9/2014 8:42
# 4      618874  666     1/26/2015 16:55
# 5      910977  318     8/29/2015 15:09
# 6      522083  337     10/30/2014 7:00
# 7      880809  394     8/7/2015 17:11
# 8      488938  766     10/8/2014 14:10
# 9      899522  531     8/21/2015 7:53
# 10     737380  267     4/23/2015 6:36
# 11     291053  766     5/20/2014 8:59
# 12     332574  416     6/20/2014 11:32
# 13     432022 4120     8/30/2014 14:44
# 14     398366  525     8/7/2014 10:09
# 15     863630  301     7/27/2015 15:20
# 16     644854  311     2/15/2015 9:10
# 17     390681  528     8/1/2014 16:57
# 18     224386 4675     3/23/2014 16:25
# 19     246380  203     4/13/2014 9:52
# 20     350371  916     7/3/2014 17:36
# 21     429032  246     8/28/2014 12:14
# 22     479700  431     10/2/2014 9:21
# 23     529387  722     11/4/2014 17:34
# 24     777536  275     5/22/2015 7:14
# 25     769331  560     5/15/2015 18:51
# 26     537257  697     11/10/2014 8:33
# 27     298292 1595     5/26/2014 13:01
# 28     485095  470     10/6/2014 16:10
# 29     109338  372     11/27/2013 7:46
# 30     416274  472     8/20/2014 8:14
# ⋮      ⋮      ⋮        ⋮
# 549932  10841 1111     9/4/2013 15:36
# 549933 155867  523     1/16/2014 14:44
# 549934 322105  906     6/12/2014 17:29
# 549935 865329  600     7/28/2015 13:09
# 549936 419180  290     8/21/2014 17:34
# 549937 288255  255     5/17/2014 15:31
# 549938  27175  933     9/19/2013 10:12
# 549939 716966  180     4/8/2015 16:03
# 549940 422409  478     8/25/2014 7:40
# 549941 599416  682     1/11/2015 19:05
# 549942 860647  878     7/24/2015 10:55
# 549943 174919  523     2/3/2014 20:37
# 549944 449873  266     9/12/2014 9:49
# 549945 711539  771     4/3/2015 17:01
# 549946 150716  370     1/12/2014 17:04
# 549947 172164  462     1/31/2014 9:49
# 549948 444391  830     9/9/2014 10:36
# 549949  53552  976     10/10/2013 18:36
# 549950 673387  659     3/9/2015 9:02
# 549951 102255  473     11/20/2013 17:07
# 549952 629989 1098     2/3/2015 17:01
# 549953 565782  394     12/4/2014 12:53
# 549954 443642 1474     9/8/2014 20:51
# 549955 527512  347     11/3/2014 18:00
# 549956 717951  577     4/9/2015 8:01
# 549957 154475  900     1/15/2014 15:38
# 549958  89909  832     11/9/2013 11:24
# 549959 273152  466     5/6/2014 7:50
# 549960 200932  656     3/4/2014 9:00
# 549961 821609  293     6/25/2015 8:29
#        start_station_name                            start_station_id
# 1      Harry Bridges Plaza (Ferry Building)          50
# 2      Market at 10th                                67
# 3      Market at Sansome                             77
# 4      San Francisco Caltrain 2 (330 Townsend)       69
# 5      Market at 10th                                67
# 6      Townsend at 7th                               65
# 7      2nd at South Park                             64
# 8      Powell at Post (Union Square)                 71
# 9      2nd at Folsom                                 62
# 10     Market at 4th                                 76
# 11     San Francisco Caltrain (Townsend at 4th)      70
# 12     Market at Sansome                             77
# 13     Harry Bridges Plaza (Ferry Building)          50
# 14     San Francisco Caltrain 2 (330 Townsend)       69
# 15     2nd at Townsend                               61
# 16     Powell Street BART                            39
# 17     Beale at Market                               56
# 18     Harry Bridges Plaza (Ferry Building)          50
# 19     Embarcadero at Bryant                         54
# 20     Temporary Transbay Terminal (Howard at Beale) 55
# 21     2nd at South Park                             64
# 22     Market at Sansome                             77
# 23     Howard at 2nd                                 63
# 24     Temporary Transbay Terminal (Howard at Beale) 55
# 25     Steuart at Market                             74
# 26     Rengstorff Avenue / California Street         33
# 27     Harry Bridges Plaza (Ferry Building)          50
# 28     2nd at Townsend                               61
# 29     San Jose Diridon Caltrain Station              2
# 30     Grant Avenue at Columbus Avenue               73
# ⋮      ⋮                                             ⋮
# 549932 Market at Sansome                             77
# 549933 2nd at South Park                             64
# 549934 Embarcadero at Sansome                        60
# 549935 Harry Bridges Plaza (Ferry Building)          50
# 549936 Broadway St at Battery St                     82
# 549937 San Francisco Caltrain 2 (330 Townsend)       69
# 549938 Embarcadero at Bryant                         54
# 549939 Market at 10th                                67
# 549940 Civic Center BART (7th at Market)             72
# 549941 Embarcadero at Sansome                        60
# 549942 SJSU 4th at San Carlos                        12
# 549943 Market at 10th                                67
# 549944 Mountain View Caltrain Station                28
# 549945 Temporary Transbay Terminal (Howard at Beale) 55
# 549946 Market at 10th                                67
# 549947 Harry Bridges Plaza (Ferry Building)          50
# 549948 Market at Sansome                             77
# 549949 Washington at Kearney                         46
# 549950 San Francisco Caltrain 2 (330 Townsend)       69
# 549951 Market at Sansome                             77
# 549952 Temporary Transbay Terminal (Howard at Beale) 55
# 549953 2nd at Folsom                                 62
# 549954 Clay at Battery                               41
# 549955 Post at Kearny                                47
# 549956 Market at 10th                                67
# 549957 Embarcadero at Sansome                        60
# 549958 2nd at Townsend                               61
# 549959 San Francisco Caltrain 2 (330 Townsend)       69
# 549960 Powell at Post (Union Square)                 71
# 549961 Steuart at Market                             74
#        end_date         end_station_name
# 1      8/27/2015 8:43   Embarcadero at Sansome
# 2      7/28/2014 22:17  Washington at Kearny
# 3      6/9/2014 8:47    2nd at Folsom
# 4      1/26/2015 17:07  Temporary Transbay Terminal (Howard at Beale)
# 5      8/29/2015 15:14  Powell Street BART
# 6      10/30/2014 7:06  San Francisco Caltrain (Townsend at 4th)
# 7      8/7/2015 17:17   2nd at Townsend
# 8      10/8/2014 14:23  San Francisco Caltrain (Townsend at 4th)
# 9      8/21/2015 8:02   San Francisco Caltrain (Townsend at 4th)
# 10     4/23/2015 6:40   Mechanics Plaza (Market at Battery)
# 11     5/20/2014 9:12   Market at 10th
# 12     6/20/2014 11:39  Civic Center BART (7th at Market)
# 13     8/30/2014 15:52  Embarcadero at Folsom
# 14     8/7/2014 10:17   Embarcadero at Folsom
# 15     7/27/2015 15:25  San Francisco Caltrain (Townsend at 4th)
# 16     2/15/2015 9:15   Market at 4th
# 17     8/1/2014 17:06   2nd at Townsend
# 18     3/23/2014 17:43  Harry Bridges Plaza (Ferry Building)
# 19     4/13/2014 9:55   Embarcadero at Folsom
# 20     7/3/2014 17:51   South Van Ness at Market
# 21     8/28/2014 12:18  Embarcadero at Bryant
# 22     10/2/2014 9:28   2nd at South Park
# 23     11/4/2014 17:46  Townsend at 7th
# 24     5/22/2015 7:19   Commercial at Montgomery
# 25     5/15/2015 19:00  2nd at Townsend
# 26     11/10/2014 8:45  Mountain View Caltrain Station
# 27     5/26/2014 13:28  Harry Bridges Plaza (Ferry Building)
# 28     10/6/2014 16:18  Harry Bridges Plaza (Ferry Building)
# 29     11/27/2013 7:53  San Pedro Square
# 30     8/20/2014 8:22   Market at Sansome
# ⋮      ⋮                ⋮
# 549932 9/4/2013 15:55   Harry Bridges Plaza (Ferry Building)
# 549933 1/16/2014 14:52  Beale at Market
# 549934 6/12/2014 17:44  Steuart at Market
# 549935 7/28/2015 13:19  Market at 4th
# 549936 8/21/2014 17:39  Mechanics Plaza (Market at Battery)
# 549937 5/17/2014 15:35  2nd at Townsend
# 549938 9/19/2013 10:27  Embarcadero at Vallejo
# 549939 4/8/2015 16:06   Civic Center BART (7th at Market)
# 549940 8/25/2014 7:48   Townsend at 7th
# 549941 1/11/2015 19:17  Post at Kearny
# 549942 7/24/2015 11:10  Arena Green / SAP Center
# 549943 2/3/2014 20:45   Yerba Buena Center of the Arts (3rd @ Howard)
# 549944 9/12/2014 9:53   Mountain View City Hall
# 549945 4/3/2015 17:14   San Francisco Caltrain (Townsend at 4th)
# 549946 1/12/2014 17:10  Market at 4th
# 549947 1/31/2014 9:57   2nd at Townsend
# 549948 9/9/2014 10:49   San Francisco Caltrain (Townsend at 4th)
# 549949 10/10/2013 18:52 Powell Street BART
# 549950 3/9/2015 9:13    Powell Street BART
# 549951 11/20/2013 17:14 Civic Center BART (7th at Market)
# 549952 2/3/2015 17:19   2nd at Townsend
# 549953 12/4/2014 13:00  5th at Howard
# 549954 9/8/2014 21:16   Civic Center BART (7th at Market)
# 549955 11/3/2014 18:05  Grant Avenue at Columbus Avenue
# 549956 4/9/2015 8:11    San Francisco Caltrain (Townsend at 4th)
# 549957 1/15/2014 15:53  San Francisco Caltrain (Townsend at 4th)
# 549958 11/9/2013 11:38  Embarcadero at Sansome
# 549959 5/6/2014 7:57    5th at Howard
# 549960 3/4/2014 9:11    Townsend at 7th
# 549961 6/25/2015 8:34   Embarcadero at Sansome
#        end_station_id bike_id subscription_type zip_code
# 1      60             187     Subscriber        94602
# 2      46             417     Subscriber        94133
# 3      62             281     Subscriber        94107
# 4      55             634     Subscriber        94602
# 5      39             607     Subscriber        94709
# 6      70             370     Subscriber        94107
# 7      61             443     Subscriber        94107
# 8      70             485     Subscriber        94107
# 9      70             603     Subscriber        94549
# 10     75              86     Customer          21202
# 11     67             528     Subscriber        95112
# 12     72             284     Subscriber        94960
# 13     51             659     Customer          94952
# 14     51             592     Subscriber        94107
# 15     70             524     Subscriber        94107
# 16     76             325     Customer          79932
# 17     61             507     Subscriber        94107
# 18     50             415     Customer          90717
# 19     51             344     Subscriber        94111
# 20     66             524     Subscriber        94612
# 21     54             422     Customer          94117
# 22     64             279     Subscriber        94501
# 23     65             134     Subscriber        94110
# 24     45             348     Subscriber        94611
# 25     61             475     Subscriber        94158
# 26     28             177     Subscriber        94040-1724
# 27     50             392     Customer          92620
# 28     50             401     Subscriber        94904
# 29      6              20     Subscriber        95377
# 30     77             522     Subscriber        94133
# ⋮      ⋮              ⋮       ⋮                 ⋮
# 549932 50             344     Customer
# 549933 56             550     Subscriber        94611
# 549934 74             621     Subscriber        95476
# 549935 76             514     Subscriber        94709
# 549936 75             610     Subscriber        94114
# 549937 61             325     Subscriber        94107
# 549938 48             530     Customer          1071
# 549939 72             360     Subscriber        94107
# 549940 65              33     Subscriber        94706
# 549941 47             566     Subscriber        94109
# 549942 14             127     Subscriber        95112
# 549943 68             473     Subscriber        94107
# 549944 27             670     Subscriber        94114
# 549945 70             549     Subscriber        94030
# 549946 76             378     Customer
# 549947 61             371     Subscriber        94903
# 549948 70             635     Subscriber        94549
# 549949 39             369     Customer          92003
# 549950 39             350     Subscriber        94102
# 549951 72             291     Subscriber        94110
# 549952 61             532     Subscriber        94086
# 549953 57              29     Subscriber        94102
# 549954 72             212     Customer          60480
# 549955 73             276     Subscriber        94104
# 549956 70             388     Subscriber        94103
# 549957 70             529     Subscriber        95111
# 549958 60             438     Subscriber        94107
# 549959 57             367     Customer          95118
# 549960 65             587     Subscriber        94108
# 549961 60             447     Subscriber        94611

# %%
test
# Out:
#        id     start_date       start_station_name
# 1      504737 10/18/2014 11:25 Embarcadero at Sansome
# 2      530846 11/5/2014 13:00  Embarcadero at Folsom
# 3      813140 6/18/2015 17:34  San Francisco Caltrain (Townsend at 4th)
# 4      897674 8/20/2015 7:06   Civic Center BART (7th at Market)
# 5      322830 6/13/2014 8:46   San Francisco Caltrain 2 (330 Townsend)
# 6      487841 10/7/2014 21:41  2nd at Townsend
# 7      677808 3/11/2015 18:09  Market at 10th
# 8      704449 3/30/2015 17:29  Embarcadero at Vallejo
# 9      833587 7/5/2015 11:54   Market at 10th
# 10     420411 8/22/2014 13:30  Embarcadero at Vallejo
# 11     354777 7/8/2014 14:05   Embarcadero at Bryant
# 12      17809 9/11/2013 13:17  Civic Center BART (7th at Market)
# 13     854667 7/20/2015 19:45  2nd at South Park
# 14     673325 3/9/2015 8:47    2nd at Folsom
# 15     729900 4/17/2015 9:28   San Francisco Caltrain 2 (330 Townsend)
# 16       4485 8/29/2013 13:16  Commercial at Montgomery
# 17     349394 7/3/2014 8:03    Harry Bridges Plaza (Ferry Building)
# 18     784460 5/28/2015 13:27  Commercial at Montgomery
# 19     908431 8/27/2015 16:24  Embarcadero at Folsom
# 20     805578 6/12/2015 19:57  San Francisco Caltrain 2 (330 Townsend)
# 21     609571 1/19/2015 12:51  Market at Sansome
# 22     269385 5/2/2014 10:40   Washington at Kearny
# 23     227320 3/26/2014 9:27   San Francisco Caltrain 2 (330 Townsend)
# 24     658277 2/25/2015 17:38  Powell Street BART
# 25     205479 3/7/2014 13:58   Steuart at Market
# 26     429936 8/28/2014 20:09  2nd at Folsom
# 27     176953 2/5/2014 14:26   Broadway St at Battery St
# 28      64226 10/18/2013 18:35 Yerba Buena Center of the Arts (3rd @ Howard)
# 29     489619 10/8/2014 18:36  Market at Sansome
# 30     831189 7/2/2015 8:14    Embarcadero at Sansome
# ⋮      ⋮      ⋮                ⋮
# 119969  60831 10/16/2013 17:13 Market at 10th
# 119970 875546 8/4/2015 17:19   Townsend at 7th
# 119971 126578 12/16/2013 7:48  Market at Sansome
# 119997 Santa Clara at Almaden                         4              42
# 119998 San Francisco Caltrain 2 (330 Townsend)       69             288
#        subscription_type zip_code
# 1      Customer          77009
# 2      Subscriber        94132
# 3      Subscriber        94107
# 4      Subscriber        94582
# 5      Subscriber        95014
# 6      Subscriber        94115
# 7      Subscriber        94025
# 8      Subscriber        94536
# 9      Subscriber        94102
# 10     Subscriber        94114
# 11     Subscriber        94110
# 12     Subscriber        94707
# 13     Subscriber        94705
# 14     Subscriber        94107
# 15     Customer          95070
# 16     Customer          94117
# 17     Subscriber        94904
# 18     Subscriber        94709
# 19     Subscriber        94103
# 20     Subscriber        94107
# 21     Subscriber        94588
# 22     Customer          98118
# 23     Subscriber        94040
# 24     Subscriber        94107
# 25     Subscriber        94704
# 26     Subscriber        94501
# 27     Customer          94102
# 28     Subscriber        94107
# 29     Subscriber        94107
# 30     Subscriber        94111
# ⋮      ⋮                 ⋮
# 119969 Subscriber        94108
# 119970 Subscriber        94707
# 119971 Subscriber        94611
# 119972 Subscriber        94606
# 119973 Subscriber        94103
# 119974 Subscriber        94133
# 119975 Subscriber        94103
# 119976 Subscriber        95110
# 119977 Subscriber        5112
# 119978 Subscriber        94582
# 119979 Subscriber        94403
# 119980 Subscriber        94087
# 119981 Subscriber        94107
# 119982 Subscriber        94070
# 119983 Subscriber        94107
# 119984 Subscriber        94103
# 119985 Subscriber        94118
# 119986 Subscriber        95129
# 119987 Subscriber        94610
# 119988 Subscriber        94107
# 119989 Subscriber        94158
# 119990 Subscriber        94105
# 119991 Subscriber        94002
# 119992 Customer          94133
# 119993 Subscriber        92084
# 119994 Subscriber        94117
# 119995 Subscriber        94107
# 119996 Subscriber        94102
# 119997 Subscriber        94025
# 119998 Subscriber        94070

# %%
# hay que adaptar nuestros campos a los que usó Luis para ese set de datos

# %%
### Data Cleanup Script
###
### This script should read the train and test sets
## and produce a clean "train" and "test" datasets
## as well as labels and id variables.

## This includes feature engineering, inputing missing
## values and all the usual tricks
## You usually spend a lot of time on this script
## The data needs not to be scaled, we'll do that in
## the next script


# Load train and test datasets
train<-read.csv('./data/train.csv',stringsAsFactors=FALSE)
test<-read.csv('./data/test.csv',stringsAsFactors=FALSE)

# Add label to test set
test$Survived <- 0

# Combine train and test sets
combi <- rbind(train,test)

combi$Name <- as.character(combi$Name)
combi$Title <- sapply(combi$Name, FUN=function(x) {strsplit(x, split='[,.]')[[1]][2]})
combi$Title <- sub(' ', '', combi$Title)
combi$Title[combi$Title %in% c('Mme', 'Mlle')] <- 'Mlle'

combi$Title[combi$Title %in% c('Capt', 'Don', 'Major', 'Sir')] <- 'Sir'
combi$Title[combi$Title %in% c('Dona', 'Lady', 'the Countess', 'Jonkheer')] <- 'Lady'

combi$Title <- factor(combi$Title)
combi$Sex<-factor(combi$Sex)
combi$Fare2 <- '30+'
combi$Fare2[combi$Fare < 30 & combi$Fare >= 20] <- '20-30'
combi$Fare2[combi$Fare < 20 & combi$Fare >= 10] <- '10-20'
combi$Fare2[combi$Fare < 10] <- '00-10'

combi$Fare2<-factor(combi$Fare2)

combi$FamilySize <- combi$SibSp + combi$Parch + 1
combi$Surname <- sapply(combi$Name, FUN=function(x) {strsplit(x, split='[,.]')[[1]][1]})
combi$FamilyID <- paste(as.character(combi$FamilySize), combi$Surname, sep="")
combi$FamilyID[combi$FamilySize <= 2] <- 'Small'

famIDs <- data.frame(table(combi$FamilyID))
famIDs <- famIDs[famIDs$Freq <= 2,]
combi$FamilyID[combi$FamilyID %in% famIDs$Var1] <- 'Small'
combi$FamilyID <- factor(combi$FamilyID)


# Synthetize missing ages
Agefit <- rpart(Age ~ Pclass + Sex + SibSp + Parch + Fare + Embarked + Title + FamilySize,
                data=combi[!is.na(combi$Age),], method="anova")
combi$Age[is.na(combi$Age)] <- predict(Agefit, combi[is.na(combi$Age),])

# Cleanup missing embarking port
combi$Embarked[c(62,830)] = "S"
combi$Embarked <- factor(combi$Embarked)

# Fix missing fare
combi$Fare[1044] <- median(combi$Fare, na.rm=TRUE)

# Fix Maximum of 32 levels per factor
combi$FamilyID2 <- combi$FamilyID
combi$FamilyID2 <- as.character(combi$FamilyID2)
combi$FamilyID2[combi$FamilySize <= 3] <- 'Small'
combi$FamilyID2 <- factor(combi$FamilyID2)

# Now the fun  begins
combi$CabinLetter<-substr(combi$Cabin,1,1)
combi$CabinLetter<-factor(combi$CabinLetter)

combi$CabinLetter<-as.character(combi$CabinLetter)
combi$CabinLetter[combi$CabinLetter==""]<-"U"
combi$CabinLetter<-factor(combi$CabinLetter)

# Create Cabin Number
combi$CabinNum<-gsub('[^0-9]',"",substr(combi$Cabin,1,4))
combi$CabinNum[combi$CabinNum==""]<-0

# Create Cabin Type
combi$Cabintype[(as.numeric(combi$CabinNum) %% 2) == 0] <- "even"
combi$Cabintype[(as.numeric(combi$CabinNum) %% 2) == 1] <- "odd"
combi$Cabintype[(as.numeric(combi$CabinNum) ==0) ] <- "unknown"
combi$Cabintype<-factor(combi$Cabintype)

# Add cabinnum2
combi$Cabinnum2<-as.numeric(combi$CabinNum) %/% 10
combi$Cabinnum2<-factor(combi$Cabinnum2)

# Fix Mrs Anderson
combi$SibSp[69]<-0
combi$Parch[69]<-0
combi$SibSp[1106]<-0
combi$Parch[1106]<-0

combi$HasFamily<-as.numeric(combi$FamilySize)>1
combi$HasFamily<-factor(combi$HasFamily)

combi$multicabin<-nchar(combi$Cabin)>3
combi$multicabin<-factor(combi$multicabin)
combi$hascharge<-grepl("\\(",combi$Name)
combi$hascharge<-factor(combi$hascharge)


rm(famIDs)

combi$Name<-NULL
combi$Ticket<-NULL
combi$Cabin<-NULL
combi$Surname<-NULL
combi$CabinNum<-NULL


combi$PassengerId<-NULL

combi$SibSp<-as.factor(combi$SibSp)
combi$Parch<-as.factor(combi$Parch)
combi$Pclass<-as.factor(combi$Pclass)

# Get Ids
id<-test$PassengerId

# Move label to first column
labels<-as.data.frame(train$Survived)
names(labels)<-"label"
combi$Survived<-NULL
#combi<-cbind(labels,combi)
#names(combi)[1]<-"label"
#combi$label<-as.factor(combi$label)

rm(Agefit)

# Create new prediction
train <- combi[1:891,]
test <- combi[892:1309,]
 
rm(combi)
str(train)
# Out:
# Error in match.names(clabs, names(xi)): names do not match previous names
# Traceback:
#
# 1. rbind(train, test)
# 2. rbind(deparse.level, ...)
# 3. match.names(clabs, names(xi))
# 4. stop("names do not match previous names")
